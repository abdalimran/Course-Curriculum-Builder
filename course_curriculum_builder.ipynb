# %%
import numpy as np
import pandas as pd
import requests
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
import re
import time

# %%
search_term = '+'.join("natural language processing".split(' '))
sort_by = 'most-reviewed' # most-reviewed, relevance, highest-rated, newest

# %%
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:66.0) Gecko/20100101 Firefox/66.0", 
           "Accept-Encoding":"gzip, deflate", 
           "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", 
           "DNT":"1",
           "Connection":"close",
           "Upgrade-Insecure-Requests":"1"}

chrome_options = Options()
chrome_options.add_argument("--headless")
driver = webdriver.Chrome(executable_path='./webdriver/chromedriver', options=chrome_options)

# %%
URL = "https://www.udemy.com/courses/search/?q="+search_term+'&sort='+sort_by
driver.get(URL)
time.sleep(10)
soup = BeautifulSoup(driver.page_source, "html5lib")

# %%
t20_courses = pd.DataFrame()

for course in soup.find_all(attrs={"class":"popper--popper--19faV"})[4:]:
    link = 'https://www.udemy.com'+course.find('a', attrs={'class':'udlite-custom-focus-visible'})['href']
    title = course.find('div', attrs={'class':'course-card--course-title--2f7tE'}).text
    description = course.find('p', attrs={'class':'course-card--course-headline--yIrRk'}).text
    instructor = course.find('div', attrs={'class':'course-card--instructor-list--lIA4f'}).text
    price = course.find('div', attrs={'data-purpose':'course-price-text'}).text.replace('Current price','')
    rating = course.find('span', attrs={'data-purpose':'rating-number'}).text
    no_reviews = course.find('span', attrs={'class':'course-card--reviews-text--12UpL'}).text.translate({ord(c):None for c in [',','(',')']})
    length = course.find('div', attrs={'class':'course-card--course-meta-info--1hHb3'}).find_all('span')[0].text
    no_lectures = course.find('div', attrs={'class':'course-card--course-meta-info--1hHb3'}).find_all('span')[1].text
    difficulty = course.find('div', attrs={'class':'course-card--course-meta-info--1hHb3'}).find_all('span')[2].text
    
    t20_courses = t20_courses.append({
        'link':link,
        'title':title,
        'description':description,
        'instructor':instructor,
        'price':price,
        'rating':rating,
        'no_reviews':no_reviews,
        'length':length,
        'no_lectures':no_lectures,
        'difficulty':difficulty
    }, ignore_index=True)

# %%
for row, course in t20_courses.iterrows():
    driver.get(course.link)
    soup = BeautifulSoup(driver.page_source, "html5lib")
    curriculum = {}
    for topic in soup.find_all('div', attrs={'class':'section--panel--1tqxC'}):
        topic_title = topic.find('span', attrs={'class':'section--section-title--8blTh'}).text
        subtopics = [subtopic.find('div', attrs={'class':'udlite-block-list-item-content'}).find('span').text\
                     for subtopic in topic.find('ul', attrs={'class':'unstyled-list'}).find_all('li')]
        curriculum[topic_title] = subtopics
    t20_courses.loc[row, 'curriculum']=str(curriculum)
    print("Curriculum downloaded for course: {}".format(course.title))
    time.sleep(5)
# Out:
# Curriculum downloaded for course: Data Science: Natural Language Processing (NLP) in Python
# Curriculum downloaded for course: NLP - Natural Language Processing with Python
# Curriculum downloaded for course: Natural Language Processing with Deep Learning in Python
# Curriculum downloaded for course: Deep Learning and NLP A-Z™: How to create a ChatBot
# Curriculum downloaded for course: Deep Learning: Convolutional Neural Networks in Python
# Curriculum downloaded for course: Deep Learning: Advanced NLP and RNNs
# Curriculum downloaded for course: Deep Learning: Recurrent Neural Networks in Python
# Curriculum downloaded for course: Introduction to Natural Language Processing (NLP)
# Curriculum downloaded for course: Modern Natural Language Processing in Python
# Curriculum downloaded for course: Hands On Natural Language Processing (NLP) using Python
# Curriculum downloaded for course: U&P AI - Natural Language Processing (NLP) with Python
# Curriculum downloaded for course: Learn Data Science Deep Learning, Machine Learning NLP & R
# Curriculum downloaded for course: Text Mining and Natural Language Processing in R
# Curriculum downloaded for course: 2021 Natural Language Processing in Python for Beginners
# Curriculum downloaded for course: Data Science:Data Mining & Natural Language Processing in R
# Curriculum downloaded for course: Natural Language Processing Real-World Projects in Python
# Curriculum downloaded for course: Natural Language Processing (NLP) in Python with 8 Projects
# Curriculum downloaded for course: NLTK: Build Document Classifier & Spell Checker with Python
# Curriculum downloaded for course: Natural Language Processing: NLP With Transformers in Python
# Curriculum downloaded for course: Natural Language Processing (NLP) with Python and NLTK

# %%
for row, course in t20_courses.iterrows():
    with open('curriculums/'+str(row+1)+'. '+course.link.replace('https://www.udemy.com/course/','').strip('/')+'.txt', 'w') as f:
        curriculum = eval(course.curriculum)
        for tindex, topic in enumerate(curriculum.keys()):
            f.write("{}. {}\n".format(tindex+1,topic))
            for sindex, subtopic in enumerate(curriculum[topic]):
                f.write('\t{}.{} {}\n'.format(tindex+1,sindex+1,subtopic))

# %%
driver.quit()

# %%
t20_courses.to_csv("t20_courses.csv", index=False)

# %%
from rapidfuzz import fuzz
import itertools
pd.set_option('display.max_rows', None)

# %%
topics = set()
subtopics = set()

for row, course in t20_courses.iterrows():
    curriculum = eval(course.curriculum)
    topics = topics.union(set(itertools.chain(curriculum.keys())))
    subtopics = subtopics.union(set(itertools.chain(*curriculum.values())))

# %%
import re

def remove_noise(text):
    text = re.sub(r'[^a-zA-Z ]+', '', text)
    text = re.sub(r' +', ' ', text)
    return text.strip(' \n\t').lower()

# %%
topics_cl = pd.Series(list(topics)).apply(remove_noise)
subtopics_cl = pd.Series(list(subtopics)).apply(remove_n`boise)

# %%
topics_cl.sort_values()
# Out:
# 137                                 advanced nltk topics
# 9                       annex artificial neural networks
# 93                                              appendix
# 51                                             attention
# 19                 basics of natural language processing
# 73            beginners corner working with word vectors
# 55                                    bidirectional rnns
# 105                                       bonus material
# 56                               bonus section thank you
# 36                     build your own sentiment analyzer
# 4                           build your own spam detector
# 126                     building a chatbot with deep nlp
# 138             categorizing and tagging words with nltk
# 116         cnn for nlp application sentimental analysis
# 53                                 cnn for nlp intuition
# 13                                  collecting text data
# 103             complete text cleaning and preprocessing
# 152                                  convolution indepth
# 157             convolutional neural network description
# 62                         convolutional neural networks
# 49                                               corpora
# 104                                  course introduction
# 112                                   course preparation
# 128             create your vocabulary for any nlp model
# 54                                        custom sources
# 28                         data manipulation with pandas
# 23            data mining for patterns and relationships
# 154                             data science with python
# 58                    data visualization with matplotlib
# 92                       dealing with corpus and wordnet
# 5                                     decrypting ciphers
# 81                                  deep learning basics
# 110                                deep learning for nlp
# 120                                   deep nlp intuition
# 119                                  dimension reduction
# 26             do you want to learn a specific nlp topic
# 91     effective learning strategies for machine lear...
# 37                    environment setup and installation
# 33     exploratory data analysis and data visualizati...
# 108            exploring text data for preliminary ideas
# 118    extra help with python coding for beginners fa...
# 43                             extracting info from text
# 121                                               extras
# 82                                   feature engineering
# 143               feedforward artificial neural networks
# 107    find and represent the meaning or topic of nat...
# 148          getting an idea of nlp and its applications
# 89     getting started with nltk natural language pro...
# 144                       getting the required softwares
# 8                                           google colab
# 32                             handling categorical data
# 149                              handling missing values
# 136                              handling numerical data
# 68                           how to learn more about nlp
# 52                              indepth gradient descent
# 25                                indepth loss functions
# 70                                    installation setup
# 131                                  installing software
# 38                                          introduction
# 12                                  introduction to apis
# 142    introduction to machine learning with scikitlearn
# 111                           introduction to the course
# 6      introduction to the course the key concepts an...
# 35                           introduction to this course
# 47                           keras and tensorflow basics
# 66                               language classification
# 44                              latent semantic analysis
# 2                                           loading data
# 83                    long text classification with bert
# 147                         machine learning and neurons
# 151                       machine learning basics review
# 98                     machine learning for data science
# 124                              machine learning review
# 14                          machine learning with python
# 24                                       memory networks
# 27                                  metrics for language
# 79                                        model building
# 77                          named entity recognition ner
# 155                   natural language processing basics
# 113                      natural language processing nlp
# 109       natural language processing sentiment analysis
# 96       natural language processing what is it used for
# 158                                     network analysis
# 34                                  nlp and transformers
# 40                                      nlp applications
# 150                                             nlp core
# 50                                nlp course concolusion
# 15                                   nltk and the basics
# 71                                      nltk exploration
# 140                                     numpy and pandas
# 159                          numpy introduction optional
# 130                        other chatbot implementations
# 21                  outline review and logistical things
# 135                         pandas introduction optional
# 139                       part building the seqseq model
# 11                               part data preprocessing
# 74                part improving tuning the seqseq model
# 85     part of speech tagging and named entity recogn...
# 45                         part testing the seqseq model
# 87                        part training the seqseq model
# 1                                         practical tips
# 134                                preprocessing for nlp
# 115                        processing raw text with nltk
# 65                  project automated text summarization
# 80     project imdb amazon and yelp review classifica...
# 57     project predict the sentiments of amazon customer
# 146             project predict the stock news headlines
# 0            project predicting the strength of password
# 59      project restaurant review prediction good or bad
# 127    project sentiment model with tensorflow and tr...
# 117                  project spam message classification
# 88                           project text classification
# 16                            project text summarization
# 160                   project twitter sentiment analysis
# 145                   project twitter sentiment analysis
# 72                                              projects
# 129                                  python crash course
# 99                                      python refresher
# 133                                   python text basics
# 84                                question and answering
# 3                 reading in data from different sources
# 100          reading in data from different sources in r
# 39     recurrent neural networks convolutional neural...
# 61     recurrent neural networks time series and sequ...
# 31        recursive neural networks tree neural networks
# 86                                   regular expressions
# 90       review of language modeling and neural networks
# 60                      semantics and sentiment analysis
# 78     sentiment analysis text classification practic...
# 46                      sequencetosequence models seqseq
# 114    setting up your environment faq by student req...
# 156                                                setup
# 63                                    spacy introduction
# 141                             spam text classification
# 48                    supervised learning classification
# 76                        supervised learning regression
# 75                            supervised learning theory
# 67                                   text classification
# 7      text cleaning and preprocessing in python soft...
# 18                        text data and machine learning
# 102                   text data mining from social media
# 20                               text data preprocessing
# 97                               text data visualization
# 29                   theano and tensorflow basics review
# 41                         tokenization tagging chunking
# 106                                       topic modeling
# 42                               transformer application
# 95                                 transformer intuition
# 64                            unifying wordvec and glove
# 94                         unsupervised classification r
# 122          using neural networks to solve nlp problems
# 153               webscraping extract data from webpages
# 22                                               welcome
# 10                                 welcome to the course
# 125                                      word embeddings
# 17                           word embeddings and wordvec
# 30                           word embeddings using glove
# 69                                      wordvec analysis
# 101    wordvec in detail and what is going on under t...
# 123                              working with text files
# 132                       write your own article spinner
# dtype: object

# %% [markdown]
# ## Using TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
vectorizer = TfidfVectorizer(ngram_range=(1, 5))
X = vectorizer.fit_transform(topics_cl)

# %%
tfidf_matrix = pd.DataFrame(X.todense(), columns=vectorizer.get_feature_names(), index=topics_cl)

# %%
csim_matrix = pd.DataFrame(cosine_similarity(tfidf_matrix,tfidf_matrix), columns=topics_cl, index=topics_cl)

# %%
n=15
print(csim_matrix.columns[n])
csim_matrix.loc[csim_matrix.columns[n]].sort_values(ascending=False)
# Out:
# nltk and the basics
# nltk and the basics                                                             1.000000
# nltk exploration                                                                0.131584
# keras and tensorflow basics                                                     0.096983
# deep learning basics                                                            0.089797
# advanced nltk topics                                                            0.089562
# python text basics                                                              0.089163
# theano and tensorflow basics review                                             0.078036
# natural language processing basics                                              0.071523
# categorizing and tagging words with nltk                                        0.071435
# machine learning basics review                                                  0.069473
# introduction to the course the key concepts and software tools                  0.062118
# processing raw text with nltk                                                   0.059659
# basics of natural language processing                                           0.056112
# introduction to the course                                                      0.055315
# welcome to the course                                                           0.051347
# getting the required softwares                                                  0.046603
# nlp and transformers                                                            0.043583
# getting started with nltk natural language processing toolkit                   0.041696
# part building the seqseq model                                                  0.040707
# numpy and pandas                                                                0.040397
# part testing the seqseq model                                                   0.040305
# part training the seqseq model                                                  0.040305
# question and answering                                                          0.038886
# find and represent the meaning or topic of natural language text                0.036193
# wordvec in detail and what is going on under the hood                           0.035278
# part improving tuning the seqseq model                                          0.033959
# project predict the stock news headlines                                        0.033011
# project predicting the strength of password                                     0.032893
# machine learning and neurons                                                    0.032110
# semantics and sentiment analysis                                                0.031690
# word embeddings and wordvec                                                     0.031595
# environment setup and installation                                              0.030170
# unifying wordvec and glove                                                      0.030043
# project predict the sentiments of amazon customer                               0.029625
# text data and machine learning                                                  0.026954
# complete text cleaning and preprocessing                                        0.025517
# dealing with corpus and wordnet                                                 0.024133
# outline review and logistical things                                            0.023980
# data mining for patterns and relationships                                      0.021183
# review of language modeling and neural networks                                 0.019357
# project sentiment model with tensorflow and transformers                        0.019156
# exploratory data analysis and data visualization in r                           0.018932
# project imdb amazon and yelp review classification                              0.018760
# recurrent neural networks time series and sequence data                         0.017260
# part of speech tagging and named entity recognition                             0.017055
# getting an idea of nlp and its applications                                     0.016946
# recurrent neural networks convolutional neural networks and word embeddings     0.015694
# text cleaning and preprocessing in python software packaging for pip install    0.013991
# extracting info from text                                                       0.000000
# python crash course                                                             0.000000
# create your vocabulary for any nlp model                                        0.000000
# machine learning with python                                                    0.000000
# building a chatbot with deep nlp                                                0.000000
# word embeddings                                                                 0.000000
# machine learning review                                                         0.000000
# working with text files                                                         0.000000
# using neural networks to solve nlp problems                                     0.000000
# extras                                                                          0.000000
# deep nlp intuition                                                              0.000000
# dimension reduction                                                             0.000000
# installing software                                                             0.000000
# extra help with python coding for beginners faq by student request              0.000000
# project spam message classification                                             0.000000
# cnn for nlp application sentimental analysis                                    0.000000
# project text summarization                                                      0.000000
# setting up your environment faq by student request                              0.000000
# natural language processing nlp                                                 0.000000
# course preparation                                                              0.000000
# text data preprocessing                                                         0.000000
# deep learning for nlp                                                           0.000000
# natural language processing sentiment analysis                                  0.000000
# exploring text data for preliminary ideas                                       0.000000
# welcome                                                                         0.000000
# topic modeling                                                                  0.000000
# other chatbot implementations                                                   0.000000
# collecting text data                                                            0.000000
# write your own article spinner                                                  0.000000
# build your own spam detector                                                    0.000000
# numpy introduction optional                                                     0.000000
# network analysis                                                                0.000000
# convolutional neural network description                                        0.000000
# setup                                                                           0.000000
# loading data                                                                    0.000000
# data science with python                                                        0.000000
# webscraping extract data from webpages                                          0.000000
# convolution indepth                                                             0.000000
# reading in data from different sources                                          0.000000
# nlp core                                                                        0.000000
# handling missing values                                                         0.000000
# decrypting ciphers                                                              0.000000
# course introduction                                                             0.000000
# project twitter sentiment analysis                                              0.000000
# feedforward artificial neural networks                                          0.000000
# introduction to machine learning with scikitlearn                               0.000000
# spam text classification                                                        0.000000
# google colab                                                                    0.000000
# annex artificial neural networks                                                0.000000
# part data preprocessing                                                         0.000000
# introduction to apis                                                            0.000000
# handling numerical data                                                         0.000000
# pandas introduction optional                                                    0.000000
# preprocessing for nlp                                                           0.000000
# bonus material                                                                  0.000000
# text data mining from social media                                              0.000000
# memory networks                                                                 0.000000
# beginners corner working with word vectors                                      0.000000
# build your own sentiment analyzer                                               0.000000
# installation setup                                                              0.000000
# wordvec analysis                                                                0.000000
# how to learn more about nlp                                                     0.000000
# text classification                                                             0.000000
# language classification                                                         0.000000
# project automated text summarization                                            0.000000
# introduction                                                                    0.000000
# spacy introduction                                                              0.000000
# convolutional neural networks                                                   0.000000
# project restaurant review prediction good or bad                                0.000000
# data visualization with matplotlib                                              0.000000
# nlp applications                                                                0.000000
# bonus section thank you                                                         0.000000
# bidirectional rnns                                                              0.000000
# custom sources                                                                  0.000000
# cnn for nlp intuition                                                           0.000000
# indepth gradient descent                                                        0.000000
# attention                                                                       0.000000
# nlp course concolusion                                                          0.000000
# corpora                                                                         0.000000
# supervised learning classification                                              0.000000
# tokenization tagging chunking                                                   0.000000
# sequencetosequence models seqseq                                                0.000000
# transformer application                                                         0.000000
# projects                                                                        0.000000
# introduction to this course                                                     0.000000
# latent semantic analysis                                                        0.000000
# supervised learning theory                                                      0.000000
# indepth loss functions                                                          0.000000
# reading in data from different sources in r                                     0.000000
# python refresher                                                                0.000000
# machine learning for data science                                               0.000000
# text data visualization                                                         0.000000
# natural language processing what is it used for                                 0.000000
# transformer intuition                                                           0.000000
# unsupervised classification r                                                   0.000000
# appendix                                                                        0.000000
# do you want to learn a specific nlp topic                                       0.000000
# effective learning strategies for machine learning faq by student request       0.000000
# metrics for language                                                            0.000000
# data manipulation with pandas                                                   0.000000
# project text classification                                                     0.000000
# word embeddings using glove                                                     0.000000
# regular expressions                                                             0.000000
# recursive neural networks tree neural networks                                  0.000000
# long text classification with bert                                              0.000000
# feature engineering                                                             0.000000
# handling categorical data                                                       0.000000
# practical tips                                                                  0.000000
# model building                                                                  0.000000
# sentiment analysis text classification practical projects                       0.000000
# named entity recognition ner                                                    0.000000
# supervised learning regression                                                  0.000000
# project twitter sentiment analysis                                              0.000000
# Name: nltk and the basics, dtype: float64

# %% [markdown]
# ## Checking using process

# %%
from rapidfuzz import process

process.extract("basics of natural language processing ", topics_cl, scorer=fuzz.WRatio, limit=10)
# Out:
# [('basics of natural language processing', 100.0, 19),
#  ('natural language processing basics', 95.0, 155),
#  ('natural language processing nlp', 88.44827586206895, 113),
#  ('nltk and the basics', 85.5, 15),
#  ('metrics for language', 85.5, 27),
#  ('language classification', 85.5, 66),
#  ('deep learning basics', 85.5, 81),
#  ('getting started with nltk natural language processing toolkit', 85.5, 89),
#  ('find and represent the meaning or topic of natural language text',
#   85.5,
#   107),
#  ('python text basics', 85.5, 133)]

# %% [markdown]
# ## Checking using fuzzy string matching matrix

# %%
matrix = pd.crosstab(topics_cl, topics_cl)
matrix = matrix.apply(lambda col: [fuzz.WRatio(col.name, x) for x in col.index])

# %%
n=2
print(matrix.columns[n])
matrix.loc[matrix.columns[n]].sort_values(ascending=False)
# Out:
# appendix
# col_0
# appendix                                                                        100.000000
# attention                                                                        47.058824
# outline review and logistical things                                             45.000000
# transformer application                                                          45.000000
# project predict the stock news headlines                                         45.000000
# environment setup and installation                                               45.000000
# project predict the sentiments of amazon customer                                45.000000
# getting an idea of nlp and its applications                                      45.000000
# getting started with nltk natural language processing toolkit                    45.000000
# handling categorical data                                                        45.000000
# handling missing values                                                          45.000000
# handling numerical data                                                          45.000000
# indepth gradient descent                                                         45.000000
# pandas introduction optional                                                     45.000000
# text data mining from social media                                               45.000000
# project restaurant review prediction good or bad                                 45.000000
# project predicting the strength of password                                      45.000000
# introduction to apis                                                             45.000000
# numpy and pandas                                                                 45.000000
# cnn for nlp application sentimental analysis                                     45.000000
# nlp applications                                                                 45.000000
# webscraping extract data from webpages                                           45.000000
# do you want to learn a specific nlp topic                                        42.750000
# theano and tensorflow basics review                                              42.750000
# part of speech tagging and named entity recognition                              42.750000
# nltk and the basics                                                              42.750000
# keras and tensorflow basics                                                      42.750000
# deep learning basics                                                             42.750000
# collecting text data                                                             36.642857
# bonus material                                                                   36.000000
# network analysis                                                                 33.750000
# annex artificial neural networks                                                 33.750000
# project imdb amazon and yelp review classification                               33.750000
# named entity recognition ner                                                     33.750000
# nlp and transformers                                                             33.750000
# project automated text summarization                                             33.750000
# processing raw text with nltk                                                    33.750000
# other chatbot implementations                                                    33.750000
# preprocessing for nlp                                                            33.750000
# advanced nltk topics                                                             33.750000
# reading in data from different sources in r                                      33.750000
# project sentiment model with tensorflow and transformers                         33.750000
# project twitter sentiment analysis                                               33.750000
# wordvec in detail and what is going on under the hood                            33.750000
# wordvec analysis                                                                 33.750000
# word embeddings using glove                                                      33.750000
# word embeddings and wordvec                                                      33.750000
# word embeddings                                                                  33.750000
# using neural networks to solve nlp problems                                      33.750000
# unsupervised classification r                                                    33.750000
# unifying wordvec and glove                                                       33.750000
# transformer intuition                                                            33.750000
# tokenization tagging chunking                                                    33.750000
# text data preprocessing                                                          33.750000
# text data and machine learning                                                   33.750000
# supervised learning theory                                                       33.750000
# supervised learning regression                                                   33.750000
# supervised learning classification                                               33.750000
# spam text classification                                                         33.750000
# setting up your environment faq by student request                               33.750000
# sentiment analysis text classification practical projects                        33.750000
# semantics and sentiment analysis                                                 33.750000
# review of language modeling and neural networks                                  33.750000
# regular expressions                                                              33.750000
# recurrent neural networks time series and sequence data                          33.750000
# machine learning basics review                                                   33.750000
# reading in data from different sources                                           33.750000
# question and answering                                                           33.750000
# machine learning review                                                          33.750000
# natural language processing sentiment analysis                                   33.750000
# machine learning and neurons                                                     33.750000
# data manipulation with pandas                                                    33.750000
# complete text cleaning and preprocessing                                         33.750000
# dealing with corpus and wordnet                                                  33.750000
# cnn for nlp intuition                                                            33.750000
# introduction to machine learning with scikitlearn                                33.750000
# feedforward artificial neural networks                                           33.750000
# categorizing and tagging words with nltk                                         33.750000
# feature engineering                                                              33.750000
# extracting info from text                                                        33.750000
# introduction to the course the key concepts and software tools                   33.750000
# exploring text data for preliminary ideas                                        33.750000
# build your own sentiment analyzer                                                33.750000
# latent semantic analysis                                                         33.750000
# data mining for patterns and relationships                                       33.750000
# exploratory data analysis and data visualization in r                            33.750000
# loading data                                                                     33.750000
# dimension reduction                                                              33.750000
# data science with python                                                         33.750000
# deep nlp intuition                                                               33.750000
# deep learning for nlp                                                            33.750000
# part data preprocessing                                                          32.258065
# part training the seqseq model                                                   32.062500
# data visualization with matplotlib                                               32.062500
# part improving tuning the seqseq model                                           32.062500
# text data visualization                                                          32.062500
# decrypting ciphers                                                               32.062500
# building a chatbot with deep nlp                                                 32.062500
# machine learning with python                                                     32.062500
# natural language processing nlp                                                  32.062500
# spacy introduction                                                               30.769231
# introduction                                                                     30.000000
# installing software                                                              30.000000
# metrics for language                                                             30.000000
# getting the required softwares                                                   30.000000
# course introduction                                                              29.629630
# extras                                                                           28.571429
# find and represent the meaning or topic of natural language text                 28.500000
# language classification                                                          28.500000
# topic modeling                                                                   28.500000
# project spam message classification                                              27.692308
# convolutional neural network description                                         27.692308
# project text summarization                                                       27.692308
# python text basics                                                               27.692308
# nltk exploration                                                                 27.692308
# text classification                                                              27.692308
# course preparation                                                               27.692308
# project text classification                                                      27.692308
# model building                                                                   27.272727
# nlp course concolusion                                                           26.666667
# basics of natural language processing                                            25.714286
# nlp core                                                                         25.000000
# projects                                                                         25.000000
# natural language processing basics                                               24.428571
# machine learning for data science                                                24.390244
# bonus section thank you                                                          24.000000
# write your own article spinner                                                   24.000000
# numpy introduction optional                                                      22.857143
# python crash course                                                              22.800000
# convolutional neural networks                                                    22.500000
# working with text files                                                          22.500000
# long text classification with bert                                               22.500000
# beginners corner working with word vectors                                       22.500000
# bidirectional rnns                                                               22.500000
# memory networks                                                                  22.500000
# natural language processing what is it used for                                  22.500000
# build your own spam detector                                                     22.500000
# installation setup                                                               22.500000
# convolution indepth                                                              22.500000
# part building the seqseq model                                                   22.500000
# sequencetosequence models seqseq                                                 22.500000
# recursive neural networks tree neural networks                                   22.500000
# part testing the seqseq model                                                    22.500000
# create your vocabulary for any nlp model                                         22.500000
# recurrent neural networks convolutional neural networks and word embeddings      22.500000
# effective learning strategies for machine learning faq by student request        22.500000
# python refresher                                                                 22.500000
# indepth loss functions                                                           22.500000
# text cleaning and preprocessing in python software packaging for pip install     22.500000
# how to learn more about nlp                                                      22.500000
# practical tips                                                                   22.500000
# introduction to the course                                                       21.375000
# introduction to this course                                                      21.375000
# extra help with python coding for beginners faq by student request               21.375000
# google colab                                                                     18.000000
# setup                                                                            18.000000
# custom sources                                                                   13.846154
# corpora                                                                          13.333333
# welcome                                                                          13.333333
# welcome to the course                                                            11.250000
# Name: appendix, dtype: float64

# %% [markdown]
# ## Checking using clustering

# %%
from sklearn.cluster import AffinityPropagation

af = AffinityPropagation(random_state=2021).fit(matrix)
cluster_centers_indices = af.cluster_centers_indices_
labels = af.labels_

# %%
matrix[labels==1]
# Out:
# col_0                                               advanced nltk topics  \
# row_0
# cnn for nlp intuition                                          34.146341
# deep learning for nlp                                          34.146341
# effective learning strategies for machine learn...             33.750000
# preprocessing for nlp                                          32.439024
#
# col_0                                               annex artificial neural networks  \
# row_0
# cnn for nlp intuition                                                      41.509434
# deep learning for nlp                                                      38.571429
# effective learning strategies for machine learn...                         39.375000
# preprocessing for nlp                                                      31.090909
#
# col_0                                               appendix  attention  \
# row_0
# cnn for nlp intuition                                  33.75  52.941176
# deep learning for nlp                                  33.75  40.000000
# effective learning strategies for machine learn...     22.50  30.400000
# preprocessing for nlp                                  33.75  34.200000
#
# col_0                                               basics of natural language processing  \
# row_0
# cnn for nlp intuition                                                           38.571429
# deep learning for nlp                                                           34.285714
# effective learning strategies for machine learn...                              36.486486
# preprocessing for nlp                                                           58.235294
#
# col_0                                               beginners corner working with word vectors  \
# row_0
# cnn for nlp intuition                                                                38.571429
# deep learning for nlp                                                                38.571429
# effective learning strategies for machine learn...                                   40.000000
# preprocessing for nlp                                                                42.857143
#
# col_0                                               bidirectional rnns  \
# row_0
# cnn for nlp intuition                                        38.974359
# deep learning for nlp                                        35.897436
# effective learning strategies for machine learn...           40.000000
# preprocessing for nlp                                        41.025641
#
# col_0                                               bonus material  \
# row_0
# cnn for nlp intuition                                    32.571429
# deep learning for nlp                                    36.642857
# effective learning strategies for machine learn...       38.571429
# preprocessing for nlp                                    30.535714
#
# col_0                                               bonus section thank you  \
# row_0
# cnn for nlp intuition                                             38.863636
# deep learning for nlp                                             30.227273
# effective learning strategies for machine learn...                37.173913
# preprocessing for nlp                                             31.818182
#
# col_0                                               build your own sentiment analyzer  \
# row_0
# cnn for nlp intuition                                                       42.857143
# deep learning for nlp                                                       36.642857
# effective learning strategies for machine learn...                          38.181818
# preprocessing for nlp                                                       34.285714
#
# col_0                                               ...  \
# row_0                                               ...
# cnn for nlp intuition                               ...
# deep learning for nlp                               ...
# effective learning strategies for machine learn...  ...
# preprocessing for nlp                               ...
#
# col_0                                               webscraping extract data from webpages  \
# row_0
# cnn for nlp intuition                                                            30.000000
# deep learning for nlp                                                            34.285714
# effective learning strategies for machine learn...                               40.263158
# preprocessing for nlp                                                            36.642857
#
# col_0                                                 welcome  \
# row_0
# cnn for nlp intuition                               15.545455
# deep learning for nlp                               38.571429
# effective learning strategies for machine learn...  25.714286
# preprocessing for nlp                               38.571429
#
# col_0                                               welcome to the course  \
# row_0
# cnn for nlp intuition                                           40.714286
# deep learning for nlp                                           33.333333
# effective learning strategies for machine learn...              38.571429
# preprocessing for nlp                                           31.666667
#
# col_0                                               word embeddings  \
# row_0
# cnn for nlp intuition                                     27.777778
# deep learning for nlp                                     33.333333
# effective learning strategies for machine learn...        36.000000
# preprocessing for nlp                                     33.333333
#
# col_0                                               word embeddings and wordvec  \
# row_0
# cnn for nlp intuition                                                 29.166667
# deep learning for nlp                                                 37.500000
# effective learning strategies for machine learn...                    33.333333
# preprocessing for nlp                                                 37.500000
#
# col_0                                               word embeddings using glove  \
# row_0
# cnn for nlp intuition                                                 33.333333
# deep learning for nlp                                                 37.500000
# effective learning strategies for machine learn...                    33.333333
# preprocessing for nlp                                                 41.666667
#
# col_0                                               wordvec analysis  \
# row_0
# cnn for nlp intuition                                      32.432432
# deep learning for nlp                                      32.432432
# effective learning strategies for machine learn...         33.750000
# preprocessing for nlp                                      32.432432
#
# col_0                                               wordvec in detail and what is going on under the hood  \
# row_0
# cnn for nlp intuition                                                                       40.714286
# deep learning for nlp                                                                       38.571429
# effective learning strategies for machine learn...                                          39.682540
# preprocessing for nlp                                                                       34.285714
#
# col_0                                               working with text files  \
# row_0
# cnn for nlp intuition                                             36.363636
# deep learning for nlp                                             34.545455
# effective learning strategies for machine learn...                43.043478
# preprocessing for nlp                                             34.545455
#
# col_0                                               write your own article spinner
# row_0
# cnn for nlp intuition                                                    39.215686
# deep learning for nlp                                                    35.294118
# effective learning strategies for machine learn...                       39.900000
# preprocessing for nlp                                                    39.215686
#
# [4 rows x 160 columns]

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=25, init='k-means++', max_iter=500, n_init=1)
kmeans.fit(matrix)
predicted = kmeans.predict(matrix)

# %%
matrix[predicted==21]
# Out:
# col_0                         advanced nltk topics  \
# row_0
# keras and tensorflow basics              46.808511
# machine learning and neurons             39.583333
# nlp and transformers                     47.500000
# nltk and the basics                      58.461538
# numpy and pandas                         42.222222
# question and answering                   40.714286
#
# col_0                         annex artificial neural networks  appendix  \
# row_0
# keras and tensorflow basics                          45.084746     42.75
# machine learning and neurons                         50.000000     33.75
# nlp and transformers                                 42.631579     33.75
# nltk and the basics                                  40.500000     42.75
# numpy and pandas                                     33.750000     45.00
# question and answering                               38.703704     33.75
#
# col_0                         attention  \
# row_0
# keras and tensorflow basics     47.5000
# machine learning and neurons    40.0000
# nlp and transformers            40.0000
# nltk and the basics             32.0625
# numpy and pandas                30.0000
# question and answering          50.0000
#
# col_0                         basics of natural language processing  \
# row_0
# keras and tensorflow basics                               47.500000
# machine learning and neurons                              40.923077
# nlp and transformers                                      40.500000
# nltk and the basics                                       85.500000
# numpy and pandas                                          39.375000
# question and answering                                    44.067797
#
# col_0                         beginners corner working with word vectors  \
# row_0
# keras and tensorflow basics                                    34.782609
# machine learning and neurons                                   42.857143
# nlp and transformers                                           36.000000
# nltk and the basics                                            36.000000
# numpy and pandas                                               24.137931
# question and answering                                         40.909091
#
# col_0                         bidirectional rnns  bonus material  \
# row_0
# keras and tensorflow basics            33.250000       38.571429
# machine learning and neurons           40.000000       32.142857
# nlp and transformers                   35.000000       35.294118
# nltk and the basics                    30.810811       36.363636
# numpy and pandas                       29.411765       33.333333
# question and answering                 45.000000       38.888889
#
# col_0                         bonus section thank you  \
# row_0
# keras and tensorflow basics                 30.400000
# machine learning and neurons                39.215686
# nlp and transformers                        37.209302
# nltk and the basics                         36.190476
# numpy and pandas                            35.897436
# question and answering                      44.444444
#
# col_0                         build your own sentiment analyzer  ...  \
# row_0                                                            ...
# keras and tensorflow basics                           38.000000  ...
# machine learning and neurons                          40.491803  ...
# nlp and transformers                                  39.375000  ...
# nltk and the basics                                   36.000000  ...
# numpy and pandas                                      39.375000  ...
# question and answering                                46.153846  ...
#
# col_0                         webscraping extract data from webpages  \
# row_0
# keras and tensorflow basics                                40.000000
# machine learning and neurons                               36.363636
# nlp and transformers                                       40.500000
# nltk and the basics                                        36.000000
# numpy and pandas                                           33.750000
# question and answering                                     36.666667
#
# col_0                           welcome  welcome to the course  \
# row_0
# keras and tensorflow basics   25.714286              35.625000
# machine learning and neurons  38.571429              36.734694
# nlp and transformers          38.571429              34.146341
# nltk and the basics           24.428571              45.000000
# numpy and pandas              12.857143              21.621622
# question and answering        27.692308              32.558140
#
# col_0                         word embeddings  word embeddings and wordvec  \
# row_0
# keras and tensorflow basics         38.571429                    42.222222
# machine learning and neurons        30.000000                    40.000000
# nlp and transformers                28.571429                    40.425532
# nltk and the basics                 35.294118                    41.304348
# numpy and pandas                    25.806452                    85.500000
# question and answering              37.837838                    40.816327
#
# col_0                         word embeddings using glove  wordvec analysis  \
# row_0
# keras and tensorflow basics                     33.333333         42.750000
# machine learning and neurons                    32.727273         32.062500
# nlp and transformers                            28.297872         36.944444
# nltk and the basics                             26.086957         43.428571
# numpy and pandas                                22.500000         37.500000
# question and answering                          34.897959         36.842105
#
# col_0                         wordvec in detail and what is going on under the hood  \
# row_0
# keras and tensorflow basics                                                85.5
# machine learning and neurons                                               85.5
# nlp and transformers                                                       85.5
# nltk and the basics                                                        85.5
# numpy and pandas                                                           85.5
# question and answering                                                     85.5
#
# col_0                         working with text files  \
# row_0
# keras and tensorflow basics                 32.000000
# machine learning and neurons                31.372549
# nlp and transformers                        32.558140
# nltk and the basics                         42.857143
# numpy and pandas                            20.512821
# question and answering                      29.555556
#
# col_0                         write your own article spinner
# row_0
# keras and tensorflow basics                        42.105263
# machine learning and neurons                       39.310345
# nlp and transformers                               34.054054
# nltk and the basics                                40.000000
# numpy and pandas                                   33.750000
# question and answering                             34.615385
#
# [6 rows x 160 columns]

# %%
import scipy
import scipy.cluster.hierarchy as sch

def cluster_corr(corr_array, inplace=False):
    pairwise_distances = sch.distance.pdist(corr_array)
    linkage = sch.linkage(pairwise_distances, method='complete')
    cluster_distance_threshold = pairwise_distances.max()/2
    idx_to_cluster_array = sch.fcluster(linkage, cluster_distance_threshold, 
                                        criterion='distance')
    idx = np.argsort(idx_to_cluster_array)
    
    if not inplace:
        corr_array = corr_array.copy()
    
    if isinstance(corr_array, pd.DataFrame):
        return corr_array.iloc[idx, :].T.iloc[idx, :]
    return corr_array[idx, :][:, idx]
